# %% [markdown]
# <a href="https://colab.research.google.com/github/khush3012/Python-Lab/blob/main/Pandas_Library_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 9 (Study of Pandas Library)
# ## Name: Khush Chauhan
# ##PRN : 25070123062
# ##Class : Entc - A3
# ##Date : 18/02/2026

# %%
# Pandas : Panel data
''' Used for:
Structured data
EDA
Data cleanng '''
# Out:
# ' Used for:\nStructured data \nEDA\nData cleanng '

# %%
#Declaration of Pandas

import pandas as pd
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create a data frame

data = {
    "Name" : ["Glen","Philips","Kartik","Aaryan"],
    "Marks" : [85,90,67,38]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Marks
# 0     Glen     85
# 1  Philips     90
# 2   Kartik     67
# 3   Aaryan     38

# %%
df.head()
df.tail()
# Out:
#       Name  Marks
# 0     Glen     85
# 1  Philips     90
# 2   Kartik     67
# 3   Aaryan     38

# %%
#Find the structure of tje DataFrame

df.shape
# Out:
# (4, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 8

# %%
# Display column names

df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# Check data type of each column

df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access indicidual column

df["Name"]
# Out:
# 0       Glen
# 1    Philips
# 2     Kartik
# 3     Aaryan
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    67
# 3    38
# Name: Marks, dtype: int64

# %%
#Access specific row

df.loc[1]
# Out:
# Name     Philips
# Marks         90
# Name: 1, dtype: object

# %%
#Add a new column

''' if marks 80-90-First Class
if marks>90-Distinction
if marks<80-Second class
if marks<50-Fail'''

df["Grade"] = ["Frist class","Distinction","Second class","Fail"]
df
# Out:
#       Name  Marks         Grade
# 0     Glen     85   Frist class
# 1  Philips     90   Distinction
# 2   Kartik     67  Second class
# 3   Aaryan     38          Fail

# %%
# Update the data in data frame
# Change Glen's marks to 88

df.loc[0,"Marks"] = 88
df
# Out:
#       Name  Marks         Grade
# 0     Glen     88   Frist class
# 1  Philips     90   Distinction
# 2   Kartik     67  Second class
# 3   Aaryan     38          Fail

# %%
# Delete a column

df.drop("Grade", axis = 1, inplace=True)
df
# Out:
#       Name  Marks
# 0     Glen     88
# 1  Philips     90
# 2   Kartik     67
# 3   Aaryan     38

# %%
# Perform basic statisical anlysis

mean1 = df["Marks"].mean()
mean1
# Out:
# np.float64(70.75)

# %%
mode1 = df["Marks"].mode()
mode1
# Out:
# 0    38
# 1    67
# 2    88
# 3    90
# Name: Marks, dtype: int64

# %%
min1 = df["Marks"].min()
min1
# Out:
# 38

# %%
max1 = df["Marks"].max()
max1
# Out:
# 90

# %%
# Apply Condition (filtering)
# Display students score more than 80

dis1 = df[df["Marks"] > 80]
dis1
# Out:
#       Name  Marks
# 0     Glen     88
# 1  Philips     90

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'C1':[11,21,np.nan], 'C2':[12,np.nan,np.nan], 'C3':[13,23,33]})
df1
# Out:
#      C1    C2  C3
# 0  11.0  12.0  13
# 1  21.0   NaN  23
# 2   NaN   NaN  33

# %%
df1.isna() #Boolean function
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna()
# Out:
#       C1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
df1.isna().sum()
# Out:
# C1    1
# C2    2
# C3    0
# dtype: int64

# %%
df1.dropna() #NAN rowas will be dropped
# Out:
#      C1    C2  C3
# 0  11.0  12.0  13
