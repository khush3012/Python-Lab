# %% [markdown]
# <a href="https://colab.research.google.com/github/khush3012/Python-Lab/blob/main/Categorical_Data_Analysis_using_Python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 11
# #Categorical Data Analysis using Python
# ##Name: Khush Chauhan
# ##PRN: 25070123062
# ##Batch: A3
# ##Date: 06/03/2026

# %%
import pandas as pd

Data = {
    'Order_ID' : ['01','02','03','04','05','06','07','08','09','10'],
    'Category' : ['Clothing','Electronics','Grocery','Clothing','Electronics','Grocery','Clothing','Electronics','Grocery','Clothing'],
    'Payment_method' : ['UPI','COD','UPI','COD' ,'UPI', 'COD','UPI','COD','UPI','COD'],
    'Delivery_type' : ['Standard','Express','Standard','Express','Standard','Express','Standard','Express','Standard','Express'],
    'Customer_type' : ['New','Returning','New','Returning','New','Returning','New','Returning','New','Returning'],
}

df= pd.DataFrame(Data)
print(df)
# Out:
#   Order_ID     Category Payment_method Delivery_type Customer_type
# 0       01     Clothing            UPI      Standard           New
# 1       02  Electronics            COD       Express     Returning
# 2       03      Grocery            UPI      Standard           New
# 3       04     Clothing            COD       Express     Returning
# 4       05  Electronics            UPI      Standard           New
# 5       06      Grocery            COD       Express     Returning
# 6       07     Clothing            UPI      Standard           New
# 7       08  Electronics            COD       Express     Returning
# 8       09      Grocery            UPI      Standard           New
# 9       10     Clothing            COD       Express     Returning

# %%
# 1. Frequency Count
# Count how many orders in each category

print(df['Category'].value_counts())
print(df['Payment_method'].value_counts())
print(df['Delivery_type'].value_counts())
# Out:
# Category
# Clothing       4
# Electronics    3
# Grocery        3
# Name: count, dtype: int64
# Payment_method
# UPI    5
# COD    5
# Name: count, dtype: int64
# Delivery_type
# Standard    5
# Express     5
# Name: count, dtype: int64

# %%
# 2. Unique Values
# Display all unique categories

print(df['Category'].unique())
print(df['Payment_method'].unique())
print(df['Delivery_type'].unique())
# Out:
# ['Clothing' 'Electronics' 'Grocery']
# ['UPI' 'COD']
# ['Standard' 'Express']

# %%
# 3. Number of uniques values

print(df['Category'].nunique())
print(df['Payment_method'].nunique())
print(df['Delivery_type'].nunique())
# Out:
# 3
# 2
# 2

# %%
# 4. Cross Tabulation
# Category vs Payment Method

print(pd.crosstab(df['Category'],df['Payment_method']))
# Out:
# Payment_method  COD  UPI
# Category
# Clothing          2    2
# Electronics       2    1
# Grocery           1    2

# %%
print(pd.crosstab(df['Delivery_type'],df['Customer_type']))
# Out:
# Customer_type  New  Returning
# Delivery_type
# Express          0          5
# Standard         5          0

# %%
# 5. Percentage Distribution

print(df['Category'].value_counts(normalize=True)*100)
# Out:
# Category
# Clothing       40.0
# Electronics    30.0
# Grocery        30.0
# Name: proportion, dtype: float64

# %%
# 6. Filtering Data

electronics_orders = df[df['Category'] == 'Electronics']
print(electronics_orders)
# Out:
#   Order_ID     Category Payment_method Delivery_type Customer_type
# 1       02  Electronics            COD       Express     Returning
# 4       05  Electronics            UPI      Standard           New
# 7       08  Electronics            COD       Express     Returning

# %%
#7. Grouping

print(df.groupby('Category')['Payment_method'].count())
# Out:
# Category
# Clothing       4
# Electronics    3
# Grocery        3
# Name: Payment_method, dtype: int64

# %%
# 8. Sorting

sorted_df = df.sort_values(by = 'Category')
print(sorted_df)
# Out:
#   Order_ID     Category Payment_method Delivery_type Customer_type
# 0       01     Clothing            UPI      Standard           New
# 3       04     Clothing            COD       Express     Returning
# 6       07     Clothing            UPI      Standard           New
# 9       10     Clothing            COD       Express     Returning
# 1       02  Electronics            COD       Express     Returning
# 4       05  Electronics            UPI      Standard           New
# 7       08  Electronics            COD       Express     Returning
# 2       03      Grocery            UPI      Standard           New
# 5       06      Grocery            COD       Express     Returning
# 8       09      Grocery            UPI      Standard           New

# %%
# Second dataset

import pandas as pd

df = pd.read_csv("/content/Expt11.csv")
print(df.head())
# Out:
#   Student  Gender Department Grade
# 0      S1    Male        CSE     A
# 1      S2  Female         IT     B
# 2      S3  Female        CSE     A
# 3      S4    Male        ECE     C
# 4      S5    Male         IT     B

# %%
# 1. Count students in Each Grade
# FInd how many students obtained each grade

print("Grade Frequency")
print(df['Grade'].value_counts())
# Out:
# Grade Frequency
# Grade
# B    24
# A    22
# C    14
# Name: count, dtype: int64

# %%
# 2. Percentage Distribution of Grades

print("Percentage Distribution")
print(df['Grade'].value_counts(normalize=True)*100)
# Out:
# Percentage Distribution
# Grade
# B    40.000000
# A    36.666667
# C    23.333333
# Name: proportion, dtype: float64

# %%
# 3. Number of students in Each department

print("Department Frequency")
print(df['Department'].value_counts())
# Out:
# Department Frequency
# Department
# CSE           20
# IT            18
# ECE           11
# Mechanical    11
# Name: count, dtype: int64

# %%
# 4. Gender Distribution

print("Gender Distribution")
print(df['Gender'].value_counts())
# Out:
# Gender Distribution
# Gender
# Male      30
# Female    30
# Name: count, dtype: int64

# %%
# 5. Gender vs grade analysis

print("Gender vs grade analysis")
print(pd.crosstab(df['Gender'],df['Grade']))
# Out:
# Gender vs grade analysis
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9

# %%
#6. Department vs Gender

print("Department vs Gender")
print(pd.crosstab(df['Department'],df['Gender']))
# Out:
# Department vs Gender
# Gender      Female  Male
# Department
# CSE             12     8
# ECE              5     6
# IT               9     9
# Mechanical       4     7

# %%
#7. Department vs Grade Percentage

print("Department vs Grade Percentage")
print(pd.crosstab(df['Department'],df['Grade'],normalize=True)*100)
# Out:
# Department vs Grade Percentage
# Grade               A          B         C
# Department
# CSE         21.666667   6.666667  5.000000
# ECE          3.333333   8.333333  6.666667
# IT          11.666667  13.333333  5.000000
# Mechanical   0.000000  11.666667  6.666667

# %%
# 8. Grouping Data (Department wise)

print("Department wise")
print(df.groupby('Department').count())
# Out:
# Department wise
#             Student  Gender  Grade
# Department
# CSE              20      20     20
# ECE              11      11     11
# IT               18      18     18
# Mechanical       11      11     11
