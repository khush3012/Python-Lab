# %% [markdown]
# <a href="https://colab.research.google.com/github/khush3012/Python-Lab/blob/main/Tuples%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 4
# ## Name : Khush
# ## PRN : 25070123062
# ## Batch : A-3

# %%
# Python Tuples
# Create Tuple and access tuple items
mytuple = ("Apple", "Samsung", "Google","Motorola")
print(mytuple)
print(mytuple[1])
# Out:
# ('Apple', 'Samsung', 'Google', 'Motorola')
# Samsung

# %%
mytuple = ("Peter", "Parker", "Gwen","Stacy")
# Tuples are immutable, so direct item assignment is not allowed.
# To "change" an item, you need to create a new tuple.
mytuple = mytuple[0:1] + ("Green Goblin",) + mytuple[2:]
print(mytuple)
# Out:
# ('Peter', 'Green Goblin', 'Gwen', 'Stacy')

# %%
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
# Tuples are immutable and do not have an 'append' method.
# To 'add' an item, create a new tuple by concatenation.
mytuple = mytuple + ("Tiger",)
print(mytuple)
# Out:
# ('Zebra', 'Lion', 'Rhino', 'Elephant', 'Tiger')

# %%
# Add to a tuple
mytuple = ("Cherry", "Raspberry", "Bluberry","Gooseberry")
a = ("Grapes",)
mytuple += a
print(mytuple)
# Out:
# ('Cherry', 'Raspberry', 'Bluberry', 'Gooseberry', 'Grapes')

# %%
# Slicing of a tuple
mytuple = ("Zebra", "Lion", "Rhino","Elephant")
print(mytuple[2:5])
print(mytuple[-4:-2])
print(mytuple[-4:])
tuple1=[20,30,50,60,40,10,70]
print(tuple1[1:3])
print(tuple1[1:3:1])
print(tuple1[1:5:2])
print(tuple1[1:4:3])
print(tuple1[6:4:-2])
print(tuple1[4:6:-1])
print(tuple1[-2:-4:-2])
# Out:
# ('Rhino', 'Elephant')
# ('Zebra', 'Lion')
# ('Zebra', 'Lion', 'Rhino', 'Elephant')
# [30, 50]
# [30, 50]
# [30, 60]
# [30]
# [70]
# []
# [10]

# %%
'''Students exam result stored in a tuple with three fixed field
Subject Name, Marks Obtained, and Grade'''
result = ("EDA",79,"A")
subject, marks, grade = result
print("Subject name :",subject)
print("Marks obtained :",marks)
print("Grade :",grade)
if result[1]>=75:
  print("Distinction")
# Out:
# Subject name : EDA
# Marks obtained : 79
# Grade : A
# Distinction

# %%
'''Organization records a employee's daily attendance for a week using a tuple
P for present and A for absent'''
attendance=("P","P","P","A","A","P")
print("Total number of present days :",attendance.count("P"))
print("Total number of absent days :",attendance.count("A"))
if attendance.count("A")>0:
  print("Absent atleast once")
# Out:
# Total number of present days : 4
# Total number of absent days : 2
# Absent atleast once
