# %% [markdown]
# <a href="https://colab.research.google.com/github/khush3012/Python-Lab/blob/main/Codes%20for%20Python%20assignment%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# simple_calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
# Out:
# Enter first number: 66
# Enter second number: 55
# Addition: 121.0
# Subtraction: 11.0
# Multiplication: 3630.0
# Division: 1.2

# %%
# marks_average

mark1 = float(input("Enter marks for Student 1: "))
mark2 = float(input("Enter marks for Student 2: "))
mark3 = float(input("Enter marks for Student 3: "))
mark4 = float(input("Enter marks for Student 4: "))
mark5 = float(input("Enter marks for Student 5: "))

total_marks = mark1 + mark2 + mark3 + mark4 + mark5

average_marks = total_marks / 5

print("Total Sum of marks:", total_marks)
print("Average marks:", average_marks)
# Out:
# Enter marks for Student 1: 1
# Enter marks for Student 2: 4
# Enter marks for Student 3: 5
# Enter marks for Student 4: 6
# Enter marks for Student 5: 5
# Total Sum of marks: 21.0
# Average marks: 4.2

# %%
# area_of_circle

Pi = 3.14

radius = float(input("Enter the radius of the circle: "))
area = Pi * (radius)**2

print("Area of the circle is:", area)
# Out:
# Enter the radius of the circle: 4
# Area of the circle is: 50.24

# %%
# rectangle

length = float(input("Enter length of rectangle: "))
width = float(input("Enter width of rectangle: "))

area = length * width

perimeter = 2 * (length + width)

print("Area of rectangle:", area)
print("Perimeter of rectangle:", perimeter)
# Out:
# Enter length of rectangle: 4
# Enter width of rectangle: 5
# Area of rectangle: 20.0
# Perimeter of rectangle: 18.0
